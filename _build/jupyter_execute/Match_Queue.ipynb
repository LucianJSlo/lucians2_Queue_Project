# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd
import random
import warnings
warnings.filterwarnings("ignore")
rng = np.random.default_rng(1729)

# %% [markdown]
# # Match Queue (Uniform)

# %% [markdown]
# ## The Matching Method

# %% [markdown]
# In this approach, we will seek to match every incoming party with their complement. For example, 2's are matched with 3's, 4's are matched with 1's, and 5's go right ahead. Here's an example of how we would group 10 parties who join the Queue:

# %%
# Queue: 5 3 1 1 4 2 5 2 1 3

# The 5 is matched and ready to go
# Teams: [5]
# Queue 3 1 1 4 2 5 2 1 3

# The 3 has no complements waiting so it's put in a line with other trios waiting to be matched
# Teams: [5]
# Lines: [3]
# Queue: 1 1 4 2 5 2 1 3

# The 1 has no complements waiting so it's put in a line with other solos waiting to be matched
# Teams: [5]
# Lines: [3] [1]
# Queue: 1 4 2 5 2 1 3

# The 1 still has no complements, repeat above
# Teams: [5]
# Lines: [3] [1, 1]
# Queue: 4 2 5 2 1 3

# The 4 has a complement, a 1, waiting in line so it's paired up with it and sent to another team
# Teams: [5] [4,1]
# Lines: [3] [1]
# Queue: 2 5 2 1 3

# %%
# Function for grouping parties of X with parties of 5-X
# Returns a list of all average wait times and
# a dataframe of all party size amounts that were left unmatched

def CreatePartyMatch(arrivals,sizes):
    c_arr = np.cumsum(arrivals)
    df = pd.DataFrame({'Arrival Time': c_arr, 'Party Size': sizes, 'Time Passed':arrivals})

    waits = []
    weights = []
    matches = []
    parties = []
    for i in range(4):
        matches.append([])
    
    for i in range(len(arrivals)):
        val = df.iloc[i]
        party = int(val[1])
        time = val[0]

        # if the party size is 5, add zero to average wait times
        if party == 5:
            waits.append(0)
            weights.append(0)
            parties.append(5)
            continue
        
        # Party of X's party of (5-X):
        complement = matches[4 - party]

        # Party of X doesn't have a match, keep it waiting with other partys of X
        if complement == []:
            matches[party-1].append(val)
        # Party of X found a party of (5-X), remove the first one waiting
        else:
            temp = complement.pop()
            waits.append((time - temp[0])/2)
            weights.append((time - temp[0])*temp[1]/5)
            parties.append([temp[1],val[1]])
    leftovers = []
    for m in matches:
        leftovers.append(len(m))
    dfl = pd.DataFrame({'Party Size':[1,2,3,4],'leftover amount':leftovers})

    return waits,weights,dfl,parties

# %% [markdown]
# ### Match Test with set 10 parties

# %%
arrivals = rng.uniform(0,5, size=10)
sizes = [5, 3, 1, 1, 4, 2, 5, 2, 1, 3]

avg_waits,weight,dfl,parties = CreatePartyMatch(arrivals,sizes)

for p in parties:
    print(p)
for i in range(4):
    print((i+1),":",dfl['leftover amount'][i])

print(weight)
# Out:
# 5
# [np.float64(1.0), np.float64(4.0)]
# [np.float64(3.0), np.float64(2.0)]
# 5
# [np.float64(2.0), np.float64(3.0)]
# 1 : 2
# 2 : 0
# 3 : 0
# 4 : 0
# [0, np.float64(0.8123718764446834), np.float64(7.976791643845283), 0, np.float64(2.5518698937284383)]

# %% [markdown]
# ### Match test when N = 1000, Uniform by Party

# %%
N = 1000

arrivals = rng.uniform(0,5, size=N)
sizes = np.random.randint(1, 6, size=N)

avg_waits,weight,dfl,parties = CreatePartyMatch(arrivals,sizes)

plt.figure()
plt.hist(avg_waits, bins=150, density=True, alpha=0.7)
plt.xlabel("Wq"); plt.ylabel("density"); plt.title("[Match] Party Wait in Queue, Uniform")
plt.xlim(0, 50)

print(parties)
s = pd.Series(avg_waits)
s.describe()

party_sample_unif = s
# Out:
# [[np.float64(2.0), np.float64(3.0)], 5, 5, [np.float64(3.0), np.float64(2.0)], 5, [np.float64(4.0), np.float64(1.0)], [np.float64(3.0), np.float64(2.0)], [np.float64(4.0), np.float64(1.0)], 5, [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], 5, [np.float64(1.0), np.float64(4.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(3.0), np.float64(2.0)], 5, [np.float64(4.0), np.float64(1.0)], 5, 5, [np.float64(4.0), np.float64(1.0)], 5, 5, [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], 5, 5, 5, [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], 5, 5, 5, [np.float64(2.0), np.float64(3.0)], 5, 5, 5, [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], 5, [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], 5, 5, [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, 5, [np.float64(2.0), np.float64(3.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], 5, 5, 5, 5, 5, 5, [np.float64(2.0), np.float64(3.0)], 5, 5, [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], 5, 5, [np.float64(4.0), np.float64(1.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, 5, 5, [np.float64(2.0), np.float64(3.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, 5, 5, [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, [np.float64(4.0), np.float64(1.0)], 5, 5, [np.float64(4.0), np.float64(1.0)], 5, [np.float64(4.0), np.float64(1.0)], 5, [np.float64(4.0), np.float64(1.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(4.0), np.float64(1.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], 5, [np.float64(4.0), np.float64(1.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], 5, 5, [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], 5, [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], 5, [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(4.0), np.float64(1.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, 5, [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)],  ...

# %% [markdown]
# ### Repeated N=1000 Uniform Match Trials by Party

# %%
N = 1000
means = []
medians = []

for i in range(100):
    arrivals = rng.uniform(0,5, size=N)
    sizes = np.random.randint(1, 6, size=N)

    avg_waits,weight,dfl,parties = CreatePartyMatch(arrivals,sizes)

    s = pd.Series(avg_waits)
    means.append(s.describe()[1])
    medians.append(s.describe()[5])


plt.figure()
plt.hist(medians, bins=100, density=True, alpha=0.7)
plt.xlabel("Average median"); plt.ylabel("density"); plt.title("Median wait times for N = 1000")

plt.figure()
plt.hist(means, bins=100, density=True, alpha=0.7)
plt.xlabel("Average mean"); plt.ylabel("density"); plt.title("Mean wait times for N = 1000")

party_means_unif = pd.Series(means)
party_meds_unif = pd.Series(medians)

# %% [markdown]
# ### Match Test when N = 1000 Uniform by Individual

# %%
N = 1000

arrivals = rng.uniform(0,5, size=N)
sizes = np.random.randint(1, 6, size=N)

avg_waits,weight,dfl,parties = CreatePartyMatch(arrivals,sizes)

plt.figure()
plt.hist(avg_waits, bins=200, density=True, alpha=0.7)
plt.xlabel("Wq"); plt.ylabel("density"); plt.title("[Match] Individual Wait in Queue, Uniform")
plt.xlim(0, 50)

print(parties)
s = pd.Series(weight)
s.describe()

ind_sample_unif = s
# Out:
# [5, 5, [np.float64(4.0), np.float64(1.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, [np.float64(4.0), np.float64(1.0)], 5, [np.float64(4.0), np.float64(1.0)], 5, 5, [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, 5, [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], 5, [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], 5, [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], 5, 5, [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, 5, 5, [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], 5, 5, 5, 5, [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], 5, [np.float64(4.0), np.float64(1.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(4.0), np.float64(1.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], 5, 5, [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(1.0), np.float64(4.0)], 5, 5, [np.float64(2.0), np.float64(3.0)], 5, 5, [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(1.0), np.float64(4.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, [np.float64(1.0), np.float64(4.0)], 5, 5, 5, [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, [np.float64(2.0), np.float64(3.0)], 5, [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], 5, 5, [np.float64(2.0), np.float64(3.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(1.0), np.float64(4.0)], 5, [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(1.0), np.float64(4.0)], [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0)], 5, [np.float64(1.0), np.float64(4.0)], [np.float64(1.0), np.float64(4.0)], 5, 5, [np.float64(2.0), np.float64(3.0)], [np.float64(2.0), np.float64(3.0) ...

# %% [markdown]
# ### Repeated N=1000 Uniform Match Trials by Individual

# %%
N = 1000
means = []
medians = []

for i in range(100):
    arrivals = rng.uniform(0,5, size=N)
    sizes = np.random.randint(1, 6, size=N)

    avg_waits,weight,dfl,parties = CreatePartyMatch(arrivals,sizes)

    s = pd.Series(weight)
    means.append(s.describe()[1])
    medians.append(s.describe()[5])


plt.figure()
plt.hist(medians, bins=100, density=True, alpha=0.7)
plt.xlabel("Median of Average Wait times"); plt.ylabel("density"); plt.title("Median wait times for N = 1000")

plt.figure()
plt.hist(means, bins=100, density=True, alpha=0.7)
plt.xlabel("Mean of Average Wait times"); plt.ylabel("density"); plt.title("Mean wait times for N = 1000")

ind_means_unif = pd.Series(means)
ind_meds_unif = pd.Series(medians)

# %% [markdown]
# ## Conclusion

# %%
print(party_sample_unif.describe())
print()
print("Average party mean across 100 trials:",party_means_unif.mean())
print("Average party median across 100 trials:",party_meds_unif.mean())
print()
print(ind_sample_unif.describe())
print()
print("Average individual mean across 100 trials:",ind_means_unif.mean())
print("Average individual median across 100 trials:",ind_meds_unif.mean())
# Out:
# count    590.000000
# mean      20.237149
# std       58.747956
# min        0.000000
# 25%        0.000000
# 50%        1.649596
# 75%        9.738353
# max      491.700176
# dtype: float64
#
# Average party mean across 100 trials: 22.666897515195895
# Average party median across 100 trials: 2.141096147379277
#
# count    582.000000
# mean      17.857445
# std       70.960583
# min        0.000000
# 25%        0.000000
# 50%        1.249475
# 75%        5.671319
# max      670.762375
# dtype: float64
#
# Average individual mean across 100 trials: 20.41391647177838
# Average individual median across 100 trials: 1.868936229392176

# %%
# Testing

arrivals = rng.uniform(0,5, size=1000)
sizes = np.random.randint(1, 6, size=1000)

avg_waits,weight,dfl,parties = CreatePartyMatch(arrivals,sizes)


for i in range(4):
    print((i+1),":",dfl['leftover amount'][i])
# Out:
# 1 : 0
# 2 : 0
# 3 : 30
# 4 : 56
